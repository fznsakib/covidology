# %% [markdown]
# # Twitter Fetcher

# %%
import requests
import json
import pandas as pd
import tqdm.notebook as tqdm
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import twint
import nest_asyncio
# from datetime import datetime
import datetime

# Used to fix threading error from twint
nest_asyncio.apply()

# %%
c = twint.Config()

# %%
c.Search = 'coronavirus OR COVID-19'
c.Near = 'Bristol'
c.Location = True
c.Limit = 20
c.Lang = 'en'
c.Store_csv = True
c.Show_hashtags = True
c.Count = True
c.Filter_retweets = True

c.Since = '2020-03-20'
c.Until = '2020-03-21'

c.Output = "tweets.csv"

c.Verified = False
c.Popular_tweets = True

# %%
# Test run
twint.run.Search(c)
# Out:
# 1241107251160645636 2020-03-20 21:00:01 GMT <ashtongatestad> 🏟 Statement: #AshtonGateStadium closure  Following today’s Government advice surrounding the containment and spread of COVID-19 Ashton Gate Stadium will regrettably close with immediate effect.   Read more ⬇️ #AshtonGateStadium
# 1241088369351770113 2020-03-20 19:45:00 GMT <BristolLive> One person has died in Gloucestershire https://www.bristolpost.co.uk/news/bristol-news/coronavirus-latest-uk-death-toll-3968718 …
# 1241077047364968448 2020-03-20 19:00:00 GMT <BBCBristol> Glastonbury festival becomes the latest event to be cancelled due to coronavirus. https://www.bbc.co.uk/news/entertainment-arts-51942898 …
# ...

# %%
# Get list of required cities and dates to pull tweets from
cities = ['London', 'Bristol', 'Manchester', 'Liverpool', 'Birmingham', 'Leeds', 'Oxford', 'Glasgow', 'Dublin', 'Cardiff']
dates = pd.date_range(start="2019-12-25",end="2020-03-25").tolist()

# %%
# Fetch 100 tweets for each city in date range 25-12-2019 to 25-03-2020
c.Limit = 100
c.Hide_output = True

for city in tqdm.tqdm(cities, leave=False):
    c.Near = city
    
    for date in tqdm.tqdm(dates):
        c.Since = date.strftime("%Y-%m-%d")
        c.Until = (date + datetime.timedelta(days=1)).strftime("%Y-%m-%d")
        twint.run.Search(c)
# Out:
# ...
# [+] Finished: Successfully collected 0 Tweets.
# [+] Finished: Successfully collected 0 Tweets.
# [+] Finished: Successfully collected 0 Tweets.
# [+] Finished: Successfully collected 0 Tweets.
# [+] Finished: Successfully collected 0 Tweets.
# [+] Finished: Successfully collected 0 Tweets.
# [+] Finished: Successfully collected 0 Tweets.
# [+] Finished: Successfully collected 0 Tweets.
# [+] Finished: Successfully collected 0 Tweets.
# [+] Finished: Successfully collected 0 Tweets.
# [+] Finished: Successfully collected 0 Tweets.
# [+] Finished: Successfully collected 0 Tweets.
# [+] Finished: Successfully collected 0 Tweets.
# [+] Finished: Successfully collected 0 Tweets.
# [+] Finished: Successfully collected 0 Tweets.
# [+] Finished: Successfully collected 1 Tweets.
# [+] Finished: Successfully collected 0 Tweets.
# [+] Finished: Successfully collected 0 Tweets.
# [+] Finished: Successfully collected 0 Tweets.
# [+] Finished: Successfully collected 0 Tweets.
# ...

# %%
df_normal = pd.read_csv("data/normal_tweets.csv")
df_popular = pd.read_csv("data/popular_tweets.csv")
df_verified_popular = pd.read_csv("data/verified_popular_tweets.csv")

# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', 10)
# pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Drop unnecessary columns

# %%
df_normal = df_normal.drop(columns=['conversation_id', 'created_at', 'timezone', 'quote_url', 'geo', 'source', 'user_rt_id', 'user_rt', 'retweet_id', 'retweet_date', 'translate', 'trans_src', 'trans_dest'])
df_popular = df_popular.drop(columns=['conversation_id', 'created_at', 'timezone', 'quote_url', 'geo', 'source', 'user_rt_id', 'user_rt', 'retweet_id', 'retweet_date', 'translate', 'trans_src', 'trans_dest'])
df_verified_popular = df_verified_popular.drop(columns=['conversation_id', 'created_at', 'timezone', 'quote_url', 'geo', 'source', 'user_rt_id', 'user_rt', 'retweet_id', 'retweet_date', 'translate', 'trans_src', 'trans_dest'])

# %%
df_normal.to_csv('normal_tweets.csv')
df_popular.to_csv('popular_tweets.csv')
df_verified_popular.to_csv('verified_popular_tweets.csv')

# %% [markdown]
# ## Get rid of verified tweets in other datasets by looking for duplicate ids

# %%
df_normal = pd.read_csv("normal_tweets.csv")
df_popular = pd.read_csv("popular_tweets.csv")
df_verified_popular = pd.read_csv("verified_popular_tweets.csv")

print(df_normal['id'].count(), df_popular['id'].count(), df_verified_popular['id'].count())
# Out:
# 25332 19158 7930

# %%
for tweet_id in tqdm.tqdm(df_normal['id']):
    df_verified_popular = df_verified_popular[df_verified_popular.id != tweet_id]

df_verified_popular['id'].count()
# Out:
# ...
# 7930

# %%
print(df_normal['id'].count())
print(df_popular['id'].count())
print(df_verified_popular['id'].count())
# Out:
# 16075
# 16985
# 7930

# %% [markdown]
# ## Drop columns that aren't required

# %%
df_normal = df_normal.drop(columns=['conversation_id', 'created_at', 'timezone', 'quote_url', 'geo', 'source', 'user_rt_id', 'user_rt', 'retweet_id', 'retweet_date', 'translate', 'trans_src', 'trans_dest'])
df_popular = df_popular.drop(columns=['conversation_id', 'created_at', 'timezone', 'quote_url', 'geo', 'source', 'user_rt_id', 'user_rt', 'retweet_id', 'retweet_date', 'translate', 'trans_src', 'trans_dest'])
df_verified_popular = df_verified_popular.drop(columns=['conversation_id', 'created_at', 'timezone', 'quote_url', 'geo', 'source', 'user_rt_id', 'user_rt', 'retweet_id', 'retweet_date', 'translate', 'trans_src', 'trans_dest'])

# %% [markdown]
# ## Add popular/verified columns

# %%
df_normal['popular'] = False
df_normal['verified'] = False
df_popular['popular'] = True
df_popular['verified'] = False
df_verified_popular['popular'] = True
df_verified_popular['verified'] = True

# %% [markdown]
# ## Save to CSV files

# %%
df_normal.to_csv('normal_tweets.csv', index=False)
df_popular.to_csv('popular_tweets.csv', index=False)
df_verified_popular.to_csv('verified_popular_tweets.csv', index=False)
